# %%
import json
# string으로 저장된 json 파일을 dict type을 원소로 갖는 list 형태로 open 
with open('../../Downloads/perfumes.json','r') as f:
    json_data=json.load(f)
json_data
# Out:
# [{'pk': 26120000,
#   'model': 'perfumes.perfume',
#   'fields': {'name': 'Ambre Canelle',
#    'launch_date': '1949-01-01',
#    'thumbnail': 'http://www.basenotes.net/photos/products/st/26120000.jpg',
#    'gender': 0,
#    'top_notes': [224, 480],
#    'heart_notes': [224, 259, 510, 785],
#    'base_notes': [28, 624],
#    'seasons': [3, 4],
#    'availability': False,
#    'brand': 749,
#    'categories': [3, 6],
#    'price': 169.99}},
#  {'pk': 26120001,
#   'model': 'perfumes.perfume',
#   'fields': {'name': 'Angélique Encens',
#    'launch_date': '1933-01-01',
#    'thumbnail': 'http://www.basenotes.net/photos/products/300/26120001-7236.jpg',
#    'gender': 0,
#    'top_notes': [28, 42, 472, 473, 785, 920],
#    'heart_notes': [],
#    'base_notes': [],
#    'seasons': [],
#    'availability': False,
#    'brand': 749,
#    'categories': [],
#    'price': 2000.0}},
#  {'pk': 26120002,
#   'model': 'perfumes.perfume',
#   'fields': {'name': 'Oud',
#    'launch_date': None,
# ...

# %%
print(type(json_data[0]))
# Out:
# <class 'dict'>

# %%
json_data[0]['pk']
# Out:
# 26120000

# %%
# dict 타입을 가지는 list를 dataframe으로 바꿔서 csv 파일로 내보내기
import pandas as pd
new_df = pd.DataFrame(json_data)
new_df
# Out:
#              pk             model  \
# 0      26120000  perfumes.perfume
# 1      26120001  perfumes.perfume
# 2      26120002  perfumes.perfume
# 3      26120003  perfumes.perfume
# 4      26120005  perfumes.perfume
# ...         ...               ...
# 39694  26160650  perfumes.perfume
# 39695  26160651  perfumes.perfume
# 39696  26160652  perfumes.perfume
# 39697  26160653  perfumes.perfume
# 39698  26160654  perfumes.perfume
#
#                                                   fields
# 0      {'name': 'Ambre Canelle', 'launch_date': '1949...
# 1      {'name': 'Angélique Encens', 'launch_date': '1...
# 2      {'name': 'Oud', 'launch_date': None, 'thumbnai...
# 3      {'name': 'X-Centric', 'launch_date': '2001-01-...
# 4      {'name': 'Space for Men', 'launch_date': None,...
# ...                                                  ...
# 39694  {'name': 'Boss Alive', 'launch_date': '2020-01...
# 39695  {'name': 'Acqua di Giò Profondo', 'launch_date...
# ...

# %%
df = new_df['fields']
df
# Out:
# 0        {'name': 'Ambre Canelle', 'launch_date': '1949...
# 1        {'name': 'Angélique Encens', 'launch_date': '1...
# 2        {'name': 'Oud', 'launch_date': None, 'thumbnai...
# 3        {'name': 'X-Centric', 'launch_date': '2001-01-...
# 4        {'name': 'Space for Men', 'launch_date': None,...
#                                ...
# 39694    {'name': 'Boss Alive', 'launch_date': '2020-01...
# 39695    {'name': 'Acqua di Giò Profondo', 'launch_date...
# 39696    {'name': 'Milk Musk', 'launch_date': '2020-01-...
# 39697    {'name': 'L'Ombre des Merveilles', 'launch_dat...
# 39698    {'name': 'Lychee & White Mint', 'launch_date':...
# Name: fields, Length: 39699, dtype: object

# %%
df[0].keys()
# Out:
# dict_keys(['name', 'launch_date', 'thumbnail', 'gender', 'top_notes', 'heart_notes', 'base_notes', 'seasons', 'availability', 'brand', 'categories', 'price'])

# %%
new_df.to_csv('perfume_data.csv')

# %%
# 위에 과정 한번 더 반복함
with open('../../Downloads/all_notes.json','r') as f:
    json_data=json.load(f)
json_data
# Out:
# [{'note': 'absinthe',
#   'category_idx': 11,
#   'category_name': 'beverages',
#   'season': [0, 1, 2, 3]},
#  {'note': 'acacia',
#   'category_idx': 3,
#   'category_name': 'flowers',
#   'season': [0, 1, 2, 3]},
#  {'note': 'acai berry',
#   'category_idx': 2,
#   'category_name': 'fruits_vegetables_and_nuts',
#   'season': [0, 2]},
#  {'note': 'acerola',
#   'category_idx': 2,
#   'category_name': 'fruits_vegetables_and_nuts',
#   'season': [0, 2]},
#  {'note': 'acerola blossom',
#   'category_idx': 3,
#   'category_name': 'flowers',
#   'season': [0, 1, 2, 3]},
#  {'note': 'acetyl furan',
#   'category_idx': 7,
#   'category_name': 'sweets_and_gourmand_smells',
#   'season': [3]},
#  {'note': 'agarwood (oud)',
#   'category_idx': 8,
#   'category_name': 'woods_and_mosses',
#   'season': [2, 3]},
#  {'note': 'agave',
#   'category_idx': 5,
#   'category_name': 'greens_herbs_and_fougeres',
#   'season': [1, 2]},
#  {'note': 'agave nectar',
#   'category_idx': 7,
# ...

# %%
print(type(json_data[0]))
# Out:
# <class 'dict'>

# %%
import pandas as pd
new_df = pd.DataFrame(json_data)
new_df
# Out:
#                 note  category_idx               category_name        season
# 0           absinthe            11                   beverages  [0, 1, 2, 3]
# 1             acacia             3                     flowers  [0, 1, 2, 3]
# 2         acai berry             2  fruits_vegetables_and_nuts        [0, 2]
# 3            acerola             2  fruits_vegetables_and_nuts        [0, 2]
# 4    acerola blossom             3                     flowers  [0, 1, 2, 3]
# ..               ...           ...                         ...           ...
# 968         yumberry             2  fruits_vegetables_and_nuts        [0, 2]
# 969   yunnan red tea             5   greens_herbs_and_fougeres        [1, 2]
# 970             yuzu             1               citrus_smells        [0, 1]
# 971      yuzu flower             3                     flowers  [0, 1, 2, 3]
# 972           zinnia             3                     flowers  [0, 1, 2, 3]
#
# [973 rows x 4 columns]

# %%
new_df.to_csv('all_note_data.csv')

# %%
df = pd.read_csv('all_note_data.csv')

# %%
df
# Out:
#      Unnamed: 0             note  category_idx               category_name  \
# 0             0         absinthe            11                   beverages
# 1             1           acacia             3                     flowers
# 2             2       acai berry             2  fruits_vegetables_and_nuts
# 3             3          acerola             2  fruits_vegetables_and_nuts
# 4             4  acerola blossom             3                     flowers
# ..          ...              ...           ...                         ...
# 968         968         yumberry             2  fruits_vegetables_and_nuts
# 969         969   yunnan red tea             5   greens_herbs_and_fougeres
# 970         970             yuzu             1               citrus_smells
# 971         971      yuzu flower             3                     flowers
# 972         972           zinnia             3                     flowers
#
#            season
# 0    [0, 1, 2, 3]
# 1    [0, 1, 2, 3]
# ...

# %%
notedata = pd.read_csv('all_note_data.csv')
notedata.head(3)
# Out:
#    Unnamed: 0        pk             model  \
# 0           0  26120000  perfumes.perfume
# 1           1  26120001  perfumes.perfume
# 2           2  26120002  perfumes.perfume
#
#                                               fields
# 0  {'name': 'Ambre Canelle', 'launch_date': '1949...
# 1  {'name': 'Angélique Encens', 'launch_date': '1...
# 2  {'name': 'Oud', 'launch_date': None, 'thumbnai...

# %%
file = pd.read_csv('../../Downloads/concat_perfume.csv')
file
# Out:
#              pk             model                    name launch_date  \
# 0      26120000  perfumes.perfume           Ambre Canelle  1949-01-01
# 1      26120001  perfumes.perfume        Angélique Encens  1933-01-01
# 2      26120002  perfumes.perfume                     Oud         NaN
# 3      26120003  perfumes.perfume               X-Centric  2001-01-01
# 4      26120005  perfumes.perfume           Space for Men         NaN
# ...         ...               ...                     ...         ...
# 39694  26160650  perfumes.perfume              Boss Alive  2020-01-01
# 39695  26160651  perfumes.perfume   Acqua di Giò Profondo  2020-01-01
# 39696  26160652  perfumes.perfume               Milk Musk  2020-01-01
# 39697  26160653  perfumes.perfume  L'Ombre des Merveilles  2020-01-01
# 39698  26160654  perfumes.perfume     Lychee & White Mint  2020-01-01
#
#           thumbnail  gender                            top_notes  \
# ...

# %% [markdown]
# ### 사용하지 않을 데이터 삭제

# %%
idx = file[file['availability']=='false'].index

# %%
file = file[file.availability != False]

# %%
file
# Out:
#              pk             model                    name launch_date  \
# 2      26120002  perfumes.perfume                     Oud         NaN
# 3      26120003  perfumes.perfume               X-Centric  2001-01-01
# 4      26120005  perfumes.perfume           Space for Men         NaN
# 5      26120006  perfumes.perfume                     GFT  2001-01-01
# 6      26120007  perfumes.perfume       Verveine Narcisse         NaN
# ...         ...               ...                     ...         ...
# 39694  26160650  perfumes.perfume              Boss Alive  2020-01-01
# 39695  26160651  perfumes.perfume   Acqua di Giò Profondo  2020-01-01
# 39696  26160652  perfumes.perfume               Milk Musk  2020-01-01
# 39697  26160653  perfumes.perfume  L'Ombre des Merveilles  2020-01-01
# 39698  26160654  perfumes.perfume     Lychee & White Mint  2020-01-01
#
#           thumbnail  gender                            top_notes  \
# ...

# %%
file1 = file[(file['top_notes']!='[]') | (file['heart_notes']!='[]') | (file['base_notes']!='[]')]
file1
# Out:
#              pk             model                       name launch_date  \
# 3      26120003  perfumes.perfume                  X-Centric  2001-01-01
# 5      26120006  perfumes.perfume                        GFT  2001-01-01
# 6      26120007  perfumes.perfume          Verveine Narcisse         NaN
# 7      26120008  perfumes.perfume              Citron Citron  2000-01-01
# 8      26120009  perfumes.perfume            Bayrhum-Vetiver         NaN
# ...         ...               ...                        ...         ...
# 39693  26160649  perfumes.perfume  Des Clous pour une Pelure  2020-01-01
# 39694  26160650  perfumes.perfume                 Boss Alive  2020-01-01
# 39695  26160651  perfumes.perfume      Acqua di Giò Profondo  2020-01-01
# 39696  26160652  perfumes.perfume                  Milk Musk  2020-01-01
# 39697  26160653  perfumes.perfume     L'Ombre des Merveilles  2020-01-01
#
#           thumbnail  gender                            top_notes  \
# ...

# %%
file2 = file1[file1['price']==0.00]
file2
# Out:
#              pk             model                       name launch_date  \
# 6      26120007  perfumes.perfume          Verveine Narcisse         NaN
# 8      26120009  perfumes.perfume            Bayrhum-Vetiver         NaN
# 10     26120011  perfumes.perfume                    Ragheeb         NaN
# 16     26120017  perfumes.perfume                       1805  1998-01-01
# 25     26120031  perfumes.perfume                 4H for Him  1999-01-01
# ...         ...               ...                        ...         ...
# 39693  26160649  perfumes.perfume  Des Clous pour une Pelure  2020-01-01
# 39694  26160650  perfumes.perfume                 Boss Alive  2020-01-01
# 39695  26160651  perfumes.perfume      Acqua di Giò Profondo  2020-01-01
# 39696  26160652  perfumes.perfume                  Milk Musk  2020-01-01
# 39697  26160653  perfumes.perfume     L'Ombre des Merveilles  2020-01-01
#
#           thumbnail  gender                      top_notes      heart_notes  \
# ...

# %%
finalfile = file1[file1['price']!=0.00]
finalfile
# Out:
#              pk             model                   name launch_date  \
# 3      26120003  perfumes.perfume              X-Centric  2001-01-01
# 5      26120006  perfumes.perfume                    GFT  2001-01-01
# 7      26120008  perfumes.perfume          Citron Citron  2000-01-01
# 14     26120015  perfumes.perfume    30cc / 50cc / 100cc  2001-01-01
# 17     26120018  perfumes.perfume           1872 for Men  2001-01-01
# ...         ...               ...                    ...         ...
# 39678  26160634  perfumes.perfume   The Majestic Vetiver  2020-01-01
# 39679  26160635  perfumes.perfume          The Favourite  2020-01-01
# 39681  26160637  perfumes.perfume  Gardenia & Oud Absolu  2020-01-01
# 39682  26160638  perfumes.perfume               Confetti  2020-01-01
# 39684  26160640  perfumes.perfume               Fresh As  2020-01-01
#
#           thumbnail  gender                            top_notes  \
# 3      26120003.jpg       1  [178, 224, 229, 292, 388, 395, 646]
# ...

# %%
file2.to_csv('price_zero_perfume.csv')

# %%
finalfile[finalfile['base_notes']=='[]']
# Out:
#              pk             model                   name launch_date  \
# 17     26120018  perfumes.perfume           1872 for Men  2001-01-01
# 22     26120028  perfumes.perfume   360 Degrees for Men   1995-01-01
# 37     26120043  perfumes.perfume         Lavanda Tonica  1999-01-01
# 83     26120089  perfumes.perfume           Ambre Sultan  1993-01-01
# 97     26120104  perfumes.perfume      Annayaké Pour Lui  2000-01-01
# ...         ...               ...                    ...         ...
# 39656  26160612  perfumes.perfume                 Orange  2020-01-01
# 39667  26160623  perfumes.perfume          Casino Elixir  2019-01-01
# 39681  26160637  perfumes.perfume  Gardenia & Oud Absolu  2020-01-01
# 39682  26160638  perfumes.perfume               Confetti  2020-01-01
# 39684  26160640  perfumes.perfume               Fresh As  2020-01-01
#
#           thumbnail  gender  \
# 17     26120018.jpg       1
# 22     26120028.jpg       1
# 37     26120043.jpg       0
# ...

# %%
finalfile.reset_index(inplace=True)

# %%
finalfile
# Out:
#        index        pk             model                   name launch_date  \
# 0          3  26120003  perfumes.perfume              X-Centric  2001-01-01
# 1          5  26120006  perfumes.perfume                    GFT  2001-01-01
# 2          7  26120008  perfumes.perfume          Citron Citron  2000-01-01
# 3         14  26120015  perfumes.perfume    30cc / 50cc / 100cc  2001-01-01
# 4         17  26120018  perfumes.perfume           1872 for Men  2001-01-01
# ...      ...       ...               ...                    ...         ...
# 14230  39678  26160634  perfumes.perfume   The Majestic Vetiver  2020-01-01
# 14231  39679  26160635  perfumes.perfume          The Favourite  2020-01-01
# 14232  39681  26160637  perfumes.perfume  Gardenia & Oud Absolu  2020-01-01
# 14233  39682  26160638  perfumes.perfume               Confetti  2020-01-01
# 14234  39684  26160640  perfumes.perfume               Fresh As  2020-01-01
#
# ...

# %%
del finalfile['index']
finalfile
# Out:
#              pk             model                   name launch_date  \
# 0      26120003  perfumes.perfume              X-Centric  2001-01-01
# 1      26120006  perfumes.perfume                    GFT  2001-01-01
# 2      26120008  perfumes.perfume          Citron Citron  2000-01-01
# 3      26120015  perfumes.perfume    30cc / 50cc / 100cc  2001-01-01
# 4      26120018  perfumes.perfume           1872 for Men  2001-01-01
# ...         ...               ...                    ...         ...
# 14230  26160634  perfumes.perfume   The Majestic Vetiver  2020-01-01
# 14231  26160635  perfumes.perfume          The Favourite  2020-01-01
# 14232  26160637  perfumes.perfume  Gardenia & Oud Absolu  2020-01-01
# 14233  26160638  perfumes.perfume               Confetti  2020-01-01
# 14234  26160640  perfumes.perfume               Fresh As  2020-01-01
#
#           thumbnail  gender                            top_notes  \
# 0      26120003.jpg       1  [178, 224, 229, 292, 388, 395, 646]
# ...

# %%
finalfile.to_csv('1st treatment_perfume.csv')

# %%
finalfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14235 entries, 0 to 14234
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   pk            14235 non-null  int64
#  1   model         14235 non-null  object
#  2   name          14235 non-null  object
#  3   thumbnail     14235 non-null  object
#  4   gender        14235 non-null  int64
#  5   top_notes     14235 non-null  object
#  6   heart_notes   14235 non-null  object
#  7   base_notes    14235 non-null  object
#  8   seasons       14235 non-null  object
#  9   availability  14235 non-null  bool
#  10  brand         14235 non-null  int64
#  11  categories    14235 non-null  object
#  12  price         14235 non-null  float64
# dtypes: bool(1), float64(1), int64(3), object(8)
# memory usage: 1.3+ MB

# %%
finalfile
# Out:
#              pk             model                   name     thumbnail  \
# 0      26120003  perfumes.perfume              X-Centric  26120003.jpg
# 1      26120006  perfumes.perfume                    GFT  26120006.jpg
# 2      26120008  perfumes.perfume          Citron Citron  26120008.jpg
# 3      26120015  perfumes.perfume    30cc / 50cc / 100cc  26120015.jpg
# 4      26120018  perfumes.perfume           1872 for Men  26120018.jpg
# ...         ...               ...                    ...           ...
# 14230  26160634  perfumes.perfume   The Majestic Vetiver  26160634.jpg
# 14231  26160635  perfumes.perfume          The Favourite  26160635.jpg
# 14232  26160637  perfumes.perfume  Gardenia & Oud Absolu  26160637.jpg
# 14233  26160638  perfumes.perfume               Confetti  26160638.jpg
# 14234  26160640  perfumes.perfume               Fresh As  26160640.jpg
#
#        gender                            top_notes          heart_notes  \
# ...

# %%
df= pd.read_csv('all_note_data.csv')
df
# Out:
#      Unnamed: 0             note  category_idx               category_name  \
# 0             0         absinthe            11                   beverages
# 1             1           acacia             3                     flowers
# 2             2       acai berry             2  fruits_vegetables_and_nuts
# 3             3          acerola             2  fruits_vegetables_and_nuts
# 4             4  acerola blossom             3                     flowers
# ..          ...              ...           ...                         ...
# 968         968         yumberry             2  fruits_vegetables_and_nuts
# 969         969   yunnan red tea             5   greens_herbs_and_fougeres
# 970         970             yuzu             1               citrus_smells
# 971         971      yuzu flower             3                     flowers
# 972         972           zinnia             3                     flowers
#
#            season
# 0    [0, 1, 2, 3]
# 1    [0, 1, 2, 3]
# ...

# %%
del df['Unnamed: 0']

# %%
df
# Out:
#                 note  category_idx               category_name        season
# 0           absinthe            11                   beverages  [0, 1, 2, 3]
# 1             acacia             3                     flowers  [0, 1, 2, 3]
# 2         acai berry             2  fruits_vegetables_and_nuts        [0, 2]
# 3            acerola             2  fruits_vegetables_and_nuts        [0, 2]
# 4    acerola blossom             3                     flowers  [0, 1, 2, 3]
# ..               ...           ...                         ...           ...
# 968         yumberry             2  fruits_vegetables_and_nuts        [0, 2]
# 969   yunnan red tea             5   greens_herbs_and_fougeres        [1, 2]
# 970             yuzu             1               citrus_smells        [0, 1]
# 971      yuzu flower             3                     flowers  [0, 1, 2, 3]
# 972           zinnia             3                     flowers  [0, 1, 2, 3]
#
# [973 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   note           973 non-null    object
#  1   category_idx   973 non-null    int64
#  2   category_name  973 non-null    object
#  3   season         973 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 30.5+ KB

# %%
finalfile
# Out:
#              pk             model                   name     thumbnail  \
# 0      26120003  perfumes.perfume              X-Centric  26120003.jpg
# 1      26120006  perfumes.perfume                    GFT  26120006.jpg
# 2      26120008  perfumes.perfume          Citron Citron  26120008.jpg
# 3      26120015  perfumes.perfume    30cc / 50cc / 100cc  26120015.jpg
# 4      26120018  perfumes.perfume           1872 for Men  26120018.jpg
# ...         ...               ...                    ...           ...
# 14230  26160634  perfumes.perfume   The Majestic Vetiver  26160634.jpg
# 14231  26160635  perfumes.perfume          The Favourite  26160635.jpg
# 14232  26160637  perfumes.perfume  Gardenia & Oud Absolu  26160637.jpg
# 14233  26160638  perfumes.perfume               Confetti  26160638.jpg
# 14234  26160640  perfumes.perfume               Fresh As  26160640.jpg
#
#        gender                            top_notes          heart_notes  \
# ...

# %%
finalfile[(finalfile['categories']=='[]') & (finalfile['seasons']=='[]')]
# 이 데이터를 채워야함
# Out:
#              pk             model                   name     thumbnail  \
# 4      26120018  perfumes.perfume           1872 for Men  26120018.jpg
# 15     26120043  perfumes.perfume         Lavanda Tonica  26120043.jpg
# 28     26120067  perfumes.perfume          Agua de Loewe  26120067.jpg
# 35     26120089  perfumes.perfume           Ambre Sultan  26120089.jpg
# 41     26120104  perfumes.perfume      Annayaké Pour Lui  26120104.jpg
# ...         ...               ...                    ...           ...
# 14222  26160612  perfumes.perfume                 Orange  26160612.jpg
# 14224  26160623  perfumes.perfume          Casino Elixir  26160623.jpg
# 14232  26160637  perfumes.perfume  Gardenia & Oud Absolu  26160637.jpg
# 14233  26160638  perfumes.perfume               Confetti  26160638.jpg
# 14234  26160640  perfumes.perfume               Fresh As  26160640.jpg
#
#        gender                                          top_notes heart_notes  \
# ...

# %%
season = pd.read_csv('json파일/season.csv')
season
# Out:
#    pk            model    name kor_name
# 0   1  perfumes.season  spring        봄
# 1   2  perfumes.season  summer       여름
# 2   3  perfumes.season  autumn       가을
# 3   4  perfumes.season  winter       겨울

# %%
df
# Out:
#                 note  category_idx               category_name        season
# 0           absinthe            11                   beverages  [0, 1, 2, 3]
# 1             acacia             3                     flowers  [0, 1, 2, 3]
# 2         acai berry             2  fruits_vegetables_and_nuts        [0, 2]
# 3            acerola             2  fruits_vegetables_and_nuts        [0, 2]
# 4    acerola blossom             3                     flowers  [0, 1, 2, 3]
# ..               ...           ...                         ...           ...
# 968         yumberry             2  fruits_vegetables_and_nuts        [0, 2]
# 969   yunnan red tea             5   greens_herbs_and_fougeres        [1, 2]
# 970             yuzu             1               citrus_smells        [0, 1]
# 971      yuzu flower             3                     flowers  [0, 1, 2, 3]
# 972           zinnia             3                     flowers  [0, 1, 2, 3]
#
# [973 rows x 4 columns]

# %%
cate = pd.read_csv('json파일/concat_categry.csv')
cate
# Out:
#     pk              model                                     name
# 0    1  perfumes.category                            citrus_smells
# 1    2  perfumes.category               fruits_vegetables_and_nuts
# 2    3  perfumes.category                                  flowers
# 3    4  perfumes.category                            white_flowers
# 4    5  perfumes.category                greens_herbs_and_fougeres
# 5    6  perfumes.category                                   spices
# 6    7  perfumes.category               sweets_and_gourmand_smells
# 7    8  perfumes.category                         woods_and_mosses
# 8    9  perfumes.category                       resins_and_balsams
# 9   10  perfumes.category               musk_amber_animalic_smells
# 10  11  perfumes.category                                beverages
# 11  12  perfumes.category  netural_and_synthetic_popular_and_weird

# %%
cnote = pd.read_csv('json파일/concat_notes.csv')
cnote
# Out:
#       pk          model             name  kor_name
# 0      1  perfumes.note         absinthe       압생트
# 1      2  perfumes.note           acacia      아카시아
# 2      3  perfumes.note       acai berry     아사이베리
# 3      4  perfumes.note          acerola      아세로라
# 4      5  perfumes.note  acerola blossom  아세로라 블라썸
# ..   ...            ...              ...       ...
# 968  969  perfumes.note         yumberry       염베리
# 969  970  perfumes.note   yunnan red tea   원난 레드 티
# 970  971  perfumes.note             yuzu        유즈
# 971  972  perfumes.note      yuzu flower    유즈 플라워
# 972  973  perfumes.note           zinnia       진니아
#
# [973 rows x 4 columns]

# %%
rv = pd.read_csv('json파일/review.csv')
rv
# Out:
#         pk            model  rate  \
# 0        1  perfumes.review     7
# 1        2  perfumes.review     2
# 2        3  perfumes.review     8
# 3        4  perfumes.review     2
# 4        5  perfumes.review     4
# ...    ...              ...   ...
# 6283  6284  perfumes.review     9
# 6284  6285  perfumes.review     8
# 6285  6286  perfumes.review     7
# 6286  6287  perfumes.review     8
# 6287  6288  perfumes.review     1
#
#                                                 content   perfume
# 0     Thisisagrown-uppowderyperfume.Veryfeminine.The...  26149998
# 1     Thecardamom,orangeblossom,amberandsandalwoodco...  26150000
# 2     Themainstarshereareblackcurrent,peach,andmugue...  26150001
# 3     Terribleheliotropebomb,performanceisspectacula...  26150002
# 4     Notafanofearthyscents,butIlikethisone.Woodyand...  26150002
# ...                                                 ...       ...
# 6283  I’mconfusedbyjusthowmuchIenjoythegourmandperfu...  26160552
# ...

# %%
finalfile[finalfile['pk']==26120020]
# Out:
#          pk             model  name     thumbnail  gender       top_notes  \
# 6  26120020  perfumes.perfume  1903  26120020.jpg       0  [96, 227, 395]
#
#   heart_notes            base_notes seasons  availability  brand categories  \
# 6  [178, 229]  [331, 513, 652, 900]     [3]          True   1423     [5, 6]
#
#    price
# 6  165.0

# %%
cnote[cnote['pk']==178]
# Out:
#       pk          model      name kor_name
# 177  178  perfumes.note  cardamom     카르다맘

# %%
df[df['season']=='[3]']
# Out:
#                 note  category_idx               category_name season
# 5       acetyl furan             7  sweets_and_gourmand_smells    [3]
# 8       agave nectar             7  sweets_and_gourmand_smells    [3]
# 99           biscuit             7  sweets_and_gourmand_smells    [3]
# 128            bread             7  sweets_and_gourmand_smells    [3]
# 132          brioche             7  sweets_and_gourmand_smells    [3]
# ..               ...           ...                         ...    ...
# 864            sugar             7  sweets_and_gourmand_smells    [3]
# 898         tiramisu             7  sweets_and_gourmand_smells    [3]
# 901           toffee             7  sweets_and_gourmand_smells    [3]
# 944  white chocolate             7  sweets_and_gourmand_smells    [3]
# 966           yogurt             7  sweets_and_gourmand_smells    [3]
#
# [66 rows x 4 columns]

# %%
df.sort_values(by=['category_idx'])
# Out:
#                    note  category_idx  \
# 740              pomelo             1
# 212            chinotto             1
# 541       litsea cubeba             1
# 714          petitgrain             1
# 100       bitter orange             1
# ..                  ...           ...
# 237        co2 extracts            12
# 229                clay            12
# 878                talc            12
# 257             coranol            12
# 463  isobutyl quinoline            12
#
#                                category_name        season
# 740                            citrus_smells        [0, 1]
# 212                            citrus_smells        [0, 1]
# 541                            citrus_smells        [0, 1]
# 714                            citrus_smells        [0, 1]
# 100                            citrus_smells        [0, 1]
# ..                                       ...           ...
# 237  netural_and_synthetic_popular_and_weird  [0, 1, 2, 3]
# ...

# %%
df['category_idx'].unique()
# Out:
# array([11,  3,  2,  7,  8,  5, 12,  6, 10,  9,  4,  1], dtype=int64)

# %%
df
# Out:
#                 note  category_idx               category_name        season
# 0           absinthe            11                   beverages  [0, 1, 2, 3]
# 1             acacia             3                     flowers  [0, 1, 2, 3]
# 2         acai berry             2  fruits_vegetables_and_nuts        [0, 2]
# 3            acerola             2  fruits_vegetables_and_nuts        [0, 2]
# 4    acerola blossom             3                     flowers  [0, 1, 2, 3]
# ..               ...           ...                         ...           ...
# 968         yumberry             2  fruits_vegetables_and_nuts        [0, 2]
# 969   yunnan red tea             5   greens_herbs_and_fougeres        [1, 2]
# 970             yuzu             1               citrus_smells        [0, 1]
# 971      yuzu flower             3                     flowers  [0, 1, 2, 3]
# 972           zinnia             3                     flowers  [0, 1, 2, 3]
#
# [973 rows x 4 columns]

# %%
df['season'].unique()
# Out:
# array(['[0, 1, 2, 3]', '[0, 2]', '[3]', '[2, 3]', '[1, 2]', '[0, 2, 3]',
#        '[0, 1]'], dtype=object)

# %%
a['category_idx'].unique()
# Out:
# array([11,  3, 12], dtype=int64)

# %%
df['season'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 973 entries, 0 to 972
# Series name: season
# Non-Null Count  Dtype
# --------------  -----
# 973 non-null    object
# dtypes: object(1)
# memory usage: 7.7+ KB

# %%
cate
# Out:
#     pk              model                                     name
# 0    1  perfumes.category                            citrus_smells
# 1    2  perfumes.category               fruits_vegetables_and_nuts
# 2    3  perfumes.category                                  flowers
# 3    4  perfumes.category                            white_flowers
# 4    5  perfumes.category                greens_herbs_and_fougeres
# 5    6  perfumes.category                                   spices
# 6    7  perfumes.category               sweets_and_gourmand_smells
# 7    8  perfumes.category                         woods_and_mosses
# 8    9  perfumes.category                       resins_and_balsams
# 9   10  perfumes.category               musk_amber_animalic_smells
# 10  11  perfumes.category                                beverages
# 11  12  perfumes.category  netural_and_synthetic_popular_and_weird

# %%
cate = cate.rename(columns={'pk':'category_idx'})

# %%
cate
# Out:
#     category_idx              model                                     name
# 0              1  perfumes.category                            citrus_smells
# 1              2  perfumes.category               fruits_vegetables_and_nuts
# 2              3  perfumes.category                                  flowers
# 3              4  perfumes.category                            white_flowers
# 4              5  perfumes.category                greens_herbs_and_fougeres
# 5              6  perfumes.category                                   spices
# 6              7  perfumes.category               sweets_and_gourmand_smells
# 7              8  perfumes.category                         woods_and_mosses
# 8              9  perfumes.category                       resins_and_balsams
# 9             10  perfumes.category               musk_amber_animalic_smells
# 10            11  perfumes.category                                beverages
# ...

# %%
mergefile = pd.merge(cate,df,on='category_idx')
mergefile
# Out:
#      category_idx              model                                     name  \
# 0               1  perfumes.category                            citrus_smells
# 1               1  perfumes.category                            citrus_smells
# 2               1  perfumes.category                            citrus_smells
# 3               1  perfumes.category                            citrus_smells
# 4               1  perfumes.category                            citrus_smells
# ..            ...                ...                                      ...
# 968            12  perfumes.category  netural_and_synthetic_popular_and_weird
# 969            12  perfumes.category  netural_and_synthetic_popular_and_weird
# 970            12  perfumes.category  netural_and_synthetic_popular_and_weird
# 971            12  perfumes.category  netural_and_synthetic_popular_and_weird
# 972            12  perfumes.category  netural_and_synthetic_popular_and_weird
#
# ...

# %%
df[df['note'].duplicated(keep=False)]
# Out:
#          note  category_idx                            category_name  \
# 211  chinotto            11                                beverages
# 212  chinotto             1                            citrus_smells
# 249    cognac            11                                beverages
# 250    cognac            11                                beverages
# 259      cork             8                         woods_and_mosses
# 260      cork            12  netural_and_synthetic_popular_and_weird
# 611  molasses            12  netural_and_synthetic_popular_and_weird
# 612  molasses             7               sweets_and_gourmand_smells
#
#            season
# 211  [0, 1, 2, 3]
# 212        [0, 1]
# 249  [0, 1, 2, 3]
# 250  [0, 1, 2, 3]
# 259        [2, 3]
# 260  [0, 1, 2, 3]
# 611  [0, 1, 2, 3]
# 612           [3]

# %%
mergefile[mergefile['note']=='chinotto']
# Out:
#      category_idx              model           name      note  category_name  \
# 4               1  perfumes.category  citrus_smells  chinotto  citrus_smells
# 829            11  perfumes.category      beverages  chinotto      beverages
#
#            season
# 4          [0, 1]
# 829  [0, 1, 2, 3]

# %%
finalfile[finalfile['pk']==26120020]
# Out:
#          pk             model  name     thumbnail  gender       top_notes  \
# 6  26120020  perfumes.perfume  1903  26120020.jpg       0  [96, 227, 395]
#
#   heart_notes            base_notes seasons  availability  brand categories  \
# 6  [178, 229]  [331, 513, 652, 900]     [3]          True   1423     [5, 6]
#
#    price
# 6  165.0

# %%
mergefile[mergefile['season']=='[3]']
# Out:
#      category_idx              model                        name  \
# 582             7  perfumes.category  sweets_and_gourmand_smells
# 583             7  perfumes.category  sweets_and_gourmand_smells
# 584             7  perfumes.category  sweets_and_gourmand_smells
# 585             7  perfumes.category  sweets_and_gourmand_smells
# 586             7  perfumes.category  sweets_and_gourmand_smells
# ..            ...                ...                         ...
# 643             7  perfumes.category  sweets_and_gourmand_smells
# 644             7  perfumes.category  sweets_and_gourmand_smells
# 645             7  perfumes.category  sweets_and_gourmand_smells
# 646             7  perfumes.category  sweets_and_gourmand_smells
# 647             7  perfumes.category  sweets_and_gourmand_smells
#
#                 note               category_name season
# 582     acetyl furan  sweets_and_gourmand_smells    [3]
# 583     agave nectar  sweets_and_gourmand_smells    [3]
# ...

# %%
df
# Out:
#                 note  category_idx               category_name        season
# 0           absinthe            11                   beverages  [0, 1, 2, 3]
# 1             acacia             3                     flowers  [0, 1, 2, 3]
# 2         acai berry             2  fruits_vegetables_and_nuts        [0, 2]
# 3            acerola             2  fruits_vegetables_and_nuts        [0, 2]
# 4    acerola blossom             3                     flowers  [0, 1, 2, 3]
# ..               ...           ...                         ...           ...
# 968         yumberry             2  fruits_vegetables_and_nuts        [0, 2]
# 969   yunnan red tea             5   greens_herbs_and_fougeres        [1, 2]
# 970             yuzu             1               citrus_smells        [0, 1]
# 971      yuzu flower             3                     flowers  [0, 1, 2, 3]
# 972           zinnia             3                     flowers  [0, 1, 2, 3]
#
# [973 rows x 4 columns]

# %%
mergefile[mergefile['category_idx']==5]
# Out:
#      category_idx              model                       name  \
# 395             5  perfumes.category  greens_herbs_and_fougeres
# 396             5  perfumes.category  greens_herbs_and_fougeres
# 397             5  perfumes.category  greens_herbs_and_fougeres
# 398             5  perfumes.category  greens_herbs_and_fougeres
# 399             5  perfumes.category  greens_herbs_and_fougeres
# ..            ...                ...                        ...
# 522             5  perfumes.category  greens_herbs_and_fougeres
# 523             5  perfumes.category  greens_herbs_and_fougeres
# 524             5  perfumes.category  greens_herbs_and_fougeres
# 525             5  perfumes.category  greens_herbs_and_fougeres
# 526             5  perfumes.category  greens_herbs_and_fougeres
#
#                         note              category_name  season
# 395                    agave  greens_herbs_and_fougeres  [1, 2]
# 396                    algae  greens_herbs_and_fougeres  [1, 2]
# ...

# %%
cate[cate['category_idx']==5]
# Out:
#    category_idx              model                       name
# 4             5  perfumes.category  greens_herbs_and_fougeres

# %%
df[df['category_idx']==5]
# Out:
#                         note  category_idx              category_name  season
# 7                      agave             5  greens_herbs_and_fougeres  [1, 2]
# 13                     algae             5  greens_herbs_and_fougeres  [1, 2]
# 18                 aloe vera             5  greens_herbs_and_fougeres  [1, 2]
# 36   ammophila (beach grass)             5  greens_herbs_and_fougeres  [1, 2]
# 41                  angelica             5  greens_herbs_and_fougeres  [1, 2]
# ..                       ...           ...                        ...     ...
# 927              violet leaf             5  greens_herbs_and_fougeres  [1, 2]
# 942                    wheat             5  greens_herbs_and_fougeres  [1, 2]
# 961                 wormwood             5  greens_herbs_and_fougeres  [1, 2]
# 963                   yarrow             5  greens_herbs_and_fougeres  [1, 2]
# 969           yunnan red tea             5  greens_herbs_and_fougeres  [1, 2]
#
# [132 rows x 4 columns]

# %%
cnote
# Out:
#       pk          model             name  kor_name
# 0      1  perfumes.note         absinthe       압생트
# 1      2  perfumes.note           acacia      아카시아
# 2      3  perfumes.note       acai berry     아사이베리
# 3      4  perfumes.note          acerola      아세로라
# 4      5  perfumes.note  acerola blossom  아세로라 블라썸
# ..   ...            ...              ...       ...
# 968  969  perfumes.note         yumberry       염베리
# 969  970  perfumes.note   yunnan red tea   원난 레드 티
# 970  971  perfumes.note             yuzu        유즈
# 971  972  perfumes.note      yuzu flower    유즈 플라워
# 972  973  perfumes.note           zinnia       진니아
#
# [973 rows x 4 columns]

# %%
df
# Out:
#                 note  category_idx               category_name        season
# 0           absinthe            11                   beverages  [0, 1, 2, 3]
# 1             acacia             3                     flowers  [0, 1, 2, 3]
# 2         acai berry             2  fruits_vegetables_and_nuts        [0, 2]
# 3            acerola             2  fruits_vegetables_and_nuts        [0, 2]
# 4    acerola blossom             3                     flowers  [0, 1, 2, 3]
# ..               ...           ...                         ...           ...
# 968         yumberry             2  fruits_vegetables_and_nuts        [0, 2]
# 969   yunnan red tea             5   greens_herbs_and_fougeres        [1, 2]
# 970             yuzu             1               citrus_smells        [0, 1]
# 971      yuzu flower             3                     flowers  [0, 1, 2, 3]
# 972           zinnia             3                     flowers  [0, 1, 2, 3]
#
# [973 rows x 4 columns]

# %%
idx=[]
for i in range(0,973):
    if df['note'][i] != cnote['name'][i]:
        idx.append(i)

for num in idx:
    print(num)
# Out:
# 701
# 708
# 712
# 721
# 733
# 903

# %%
df['note'][701]
# Out:
# 'pear tree'

# %%
cnote.iloc[701]
# Out:
# pk                    702
# model       perfumes.note
# name            pear leaf
# kor_name            피어 트리
# Name: 701, dtype: object

# %%
cnote.loc[701,'name']='pear tree'

# %%
cnote.iloc[701]
# Out:
# pk                    702
# model       perfumes.note
# name            pear tree
# kor_name            피어 트리
# Name: 701, dtype: object

# %%
df['note'][708]
# Out:
# 'peppertree'

# %%
cnote['name'][708]
# Out:
# 'pepperleaf'

# %%
cnote.iloc[708]
# Out:
# pk                    709
# model       perfumes.note
# name           pepperleaf
# kor_name            페퍼 트리
# Name: 708, dtype: object

# %%
cnote.loc[708,'name']='peppertree'

# %%
cnote.iloc[708]
# Out:
# pk                    709
# model       perfumes.note
# name           peppertree
# kor_name            페퍼 트리
# Name: 708, dtype: object

# %%
df['note'][712]
# Out:
# 'peru balsam'

# %%
cnote['name'][712]
# Out:
# 'peru leaf'

# %%
cnote.iloc[712]
# Out:
# pk                    713
# model       perfumes.note
# name            peru leaf
# kor_name            페루 발삼
# Name: 712, dtype: object

# %%
cnote.loc[712,'name']='peru balsam'

# %%
cnote.iloc[712]
# Out:
# pk                    713
# model       perfumes.note
# name          peru balsam
# kor_name            페루 발삼
# Name: 712, dtype: object

# %%
df['note'][721]
# Out:
# 'pine tree'

# %%
cnote['name'][721]
# Out:
# 'pine leaf'

# %%
cnote.iloc[721]
# Out:
# pk                    722
# model       perfumes.note
# name            pine leaf
# kor_name            파인 트리
# Name: 721, dtype: object

# %%
cnote.loc[721,'name']='pine tree'

# %%
cnote.iloc[721]
# Out:
# pk                    722
# model       perfumes.note
# name            pine tree
# kor_name            파인 트리
# Name: 721, dtype: object

# %%
df['note'][733]
# Out:
# 'plum tree'

# %%
cnote['name'][733]
# Out:
# 'plum leaf'

# %%
cnote.iloc[733]
# Out:
# pk                    734
# model       perfumes.note
# name            plum leaf
# kor_name            플럼 트리
# Name: 733, dtype: object

# %%
cnote.loc[733,'name']='plum tree'

# %%
cnote.iloc[733]
# Out:
# pk                    734
# model       perfumes.note
# name            plum tree
# kor_name            플럼 트리
# Name: 733, dtype: object

# %%
df['note'][903]
# Out:
# 'tolu balsam'

# %%
cnote['name'][903]
# Out:
# 'tolu leaf'

# %%
cnote.iloc[903]
# Out:
# pk                    904
# model       perfumes.note
# name            tolu leaf
# kor_name            토루 리프
# Name: 903, dtype: object

# %%
df.iloc[903]
# Out:
# note                            tolu balsam
# category_idx                             10
# category_name    musk_amber_animalic_smells
# season                               [2, 3]
# Name: 903, dtype: object

# %%
df.loc[903,'note']='tolu leaf'

# %%
df.iloc[903]
# Out:
# note                              tolu leaf
# category_idx                             10
# category_name    musk_amber_animalic_smells
# season                               [2, 3]
# Name: 903, dtype: object

# %%
idx=[]
for i in range(0,973):
    if df['note'][i] != cnote['name'][i]:
        idx.append(i)

for num in idx:
    print(num)

# %%
mergefile
# Out:
#      category_idx              model                                     name  \
# 0               1  perfumes.category                            citrus_smells
# 1               1  perfumes.category                            citrus_smells
# 2               1  perfumes.category                            citrus_smells
# 3               1  perfumes.category                            citrus_smells
# 4               1  perfumes.category                            citrus_smells
# ..            ...                ...                                      ...
# 968            12  perfumes.category  netural_and_synthetic_popular_and_weird
# 969            12  perfumes.category  netural_and_synthetic_popular_and_weird
# 970            12  perfumes.category  netural_and_synthetic_popular_and_weird
# 971            12  perfumes.category  netural_and_synthetic_popular_and_weird
# 972            12  perfumes.category  netural_and_synthetic_popular_and_weird
#
# ...

# %%
cnote
# Out:
#       pk          model             name  kor_name
# 0      1  perfumes.note         absinthe       압생트
# 1      2  perfumes.note           acacia      아카시아
# 2      3  perfumes.note       acai berry     아사이베리
# 3      4  perfumes.note          acerola      아세로라
# 4      5  perfumes.note  acerola blossom  아세로라 블라썸
# ..   ...            ...              ...       ...
# 968  969  perfumes.note         yumberry       염베리
# 969  970  perfumes.note   yunnan red tea   원난 레드 티
# 970  971  perfumes.note             yuzu        유즈
# 971  972  perfumes.note      yuzu flower    유즈 플라워
# 972  973  perfumes.note           zinnia       진니아
#
# [973 rows x 4 columns]

# %%
cnote = cnote.rename(columns={'name':'note'})
cnote
# Out:
#       pk          model             note  kor_name
# 0      1  perfumes.note         absinthe       압생트
# 1      2  perfumes.note           acacia      아카시아
# 2      3  perfumes.note       acai berry     아사이베리
# 3      4  perfumes.note          acerola      아세로라
# 4      5  perfumes.note  acerola blossom  아세로라 블라썸
# ..   ...            ...              ...       ...
# 968  969  perfumes.note         yumberry       염베리
# 969  970  perfumes.note   yunnan red tea   원난 레드 티
# 970  971  perfumes.note             yuzu        유즈
# 971  972  perfumes.note      yuzu flower    유즈 플라워
# 972  973  perfumes.note           zinnia       진니아
#
# [973 rows x 4 columns]

# %%
mergefile1 = pd.merge(cnote,mergefile,on='note')
mergefile1
# ??? 값이 왜 늘어났지?
# Out:
#       pk        model_x             note  kor_name  category_idx  \
# 0      1  perfumes.note         absinthe       압생트            11
# 1      2  perfumes.note           acacia      아카시아             3
# 2      3  perfumes.note       acai berry     아사이베리             2
# 3      4  perfumes.note          acerola      아세로라             2
# 4      5  perfumes.note  acerola blossom  아세로라 블라썸             3
# ..   ...            ...              ...       ...           ...
# 975  969  perfumes.note         yumberry       염베리             2
# 976  970  perfumes.note   yunnan red tea   원난 레드 티             5
# 977  971  perfumes.note             yuzu        유즈             1
# 978  972  perfumes.note      yuzu flower    유즈 플라워             3
# 979  973  perfumes.note           zinnia       진니아             3
#
#                model_y                        name  \
# 0    perfumes.category                   beverages
# 1    perfumes.category                     flowers
# ...

# %%
mergefile1[mergefile1['pk'].duplicated(keep=False)]
# 중복된게 있다..?
# Out:
#       pk        model_x      note kor_name  category_idx            model_y  \
# 211  212  perfumes.note  chinotto      치노토             1  perfumes.category
# 212  212  perfumes.note  chinotto      치노토            11  perfumes.category
# 213  213  perfumes.note  chinotto      치노토             1  perfumes.category
# 214  213  perfumes.note  chinotto      치노토            11  perfumes.category
# 251  250  perfumes.note    cognac       코냑            11  perfumes.category
# 252  250  perfumes.note    cognac       코냑            11  perfumes.category
# 253  251  perfumes.note    cognac       코냑            11  perfumes.category
# 254  251  perfumes.note    cognac       코냑            11  perfumes.category
# 263  260  perfumes.note      cork      코르크             8  perfumes.category
# 264  260  perfumes.note      cork      코르크            12  perfumes.category
# 265  261  perfumes.note      cork      코르크             8  perfumes.category
# ...

# %%
mergefile1.drop([])

# %%
df[df['note']=='cognac']
# Out:
#        note  category_idx category_name        season
# 249  cognac            11     beverages  [0, 1, 2, 3]
# 250  cognac            11     beverages  [0, 1, 2, 3]

# %%
finalfile[finalfile['seasons']=='[]']
# Out:
#              pk             model                   name     thumbnail  \
# 4      26120018  perfumes.perfume           1872 for Men  26120018.jpg
# 15     26120043  perfumes.perfume         Lavanda Tonica  26120043.jpg
# 28     26120067  perfumes.perfume          Agua de Loewe  26120067.jpg
# 35     26120089  perfumes.perfume           Ambre Sultan  26120089.jpg
# 41     26120104  perfumes.perfume      Annayaké Pour Lui  26120104.jpg
# ...         ...               ...                    ...           ...
# 14222  26160612  perfumes.perfume                 Orange  26160612.jpg
# 14224  26160623  perfumes.perfume          Casino Elixir  26160623.jpg
# 14232  26160637  perfumes.perfume  Gardenia & Oud Absolu  26160637.jpg
# 14233  26160638  perfumes.perfume               Confetti  26160638.jpg
# 14234  26160640  perfumes.perfume               Fresh As  26160640.jpg
#
#        gender                                          top_notes heart_notes  \
# ...

# %%
pdf = pd.read_csv('cat_filled.csv')
pdf
# Out:
#              pk             model                   name     thumbnail  \
# 0      26120003  perfumes.perfume              X-Centric  26120003.jpg
# 1      26120006  perfumes.perfume                    GFT  26120006.jpg
# 2      26120008  perfumes.perfume          Citron Citron  26120008.jpg
# 3      26120015  perfumes.perfume    30cc / 50cc / 100cc  26120015.jpg
# 4      26120018  perfumes.perfume           1872 for Men  26120018.jpg
# ...         ...               ...                    ...           ...
# 14230  26160634  perfumes.perfume   The Majestic Vetiver  26160634.jpg
# 14231  26160635  perfumes.perfume          The Favourite  26160635.jpg
# 14232  26160637  perfumes.perfume  Gardenia & Oud Absolu  26160637.jpg
# 14233  26160638  perfumes.perfume               Confetti  26160638.jpg
# 14234  26160640  perfumes.perfume               Fresh As  26160640.jpg
#
#        gender                            top_notes          heart_notes  \
# ...

# %%
mergefile1
# Out:
#       pk        model_x             note  kor_name  category_idx  \
# 0      1  perfumes.note         absinthe       압생트            11
# 1      2  perfumes.note           acacia      아카시아             3
# 2      3  perfumes.note       acai berry     아사이베리             2
# 3      4  perfumes.note          acerola      아세로라             2
# 4      5  perfumes.note  acerola blossom  아세로라 블라썸             3
# ..   ...            ...              ...       ...           ...
# 975  969  perfumes.note         yumberry       염베리             2
# 976  970  perfumes.note   yunnan red tea   원난 레드 티             5
# 977  971  perfumes.note             yuzu        유즈             1
# 978  972  perfumes.note      yuzu flower    유즈 플라워             3
# 979  973  perfumes.note           zinnia       진니아             3
#
#                model_y                        name  \
# 0    perfumes.category                   beverages
# 1    perfumes.category                     flowers
# ...

# %%
seasondf = mergefile1[['category_idx','season']]
seasondf
# Out:
#      category_idx        season
# 0              11  [0, 1, 2, 3]
# 1               3  [0, 1, 2, 3]
# 2               2        [0, 2]
# 3               2        [0, 2]
# 4               3  [0, 1, 2, 3]
# ..            ...           ...
# 975             2        [0, 2]
# 976             5        [1, 2]
# 977             1        [0, 1]
# 978             3  [0, 1, 2, 3]
# 979             3  [0, 1, 2, 3]
#
# [980 rows x 2 columns]
